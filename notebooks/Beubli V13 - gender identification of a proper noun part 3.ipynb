# %% [markdown]
# # Beubli V13 - Introduction
#
# We now have a clean proper noun dataset.
# We are now interested in the infered gender of each subject.
#
# Eg. Jonas is a man, Rachel is a woman.

# %% [markdown]
# # Imports and config

# %% [markdown]
# ## Lib and dataset import

# %%
#load libs
from google.colab import files
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
np.warnings.filterwarnings('ignore')
from tqdm.notebook import tqdm
from bs4 import BeautifulSoup
import re
import pprint   # For proper print of sequences.
# import treetaggerwrapper
from nltk.tokenize import sent_tokenize 
import glob
from tqdm.notebook import tqdm
tqdm.pandas()

# %% [markdown]
# ## CamenBert install and model import

# %%
# %%bash
# pip install fairseq
# pip install sentencepiece
# wget https://dl.fbaipublicfiles.com/fairseq/models/camembert-base.tar.gz
# tar -xzvf camembert-base.tar.gz
# Out:
# ...
# camembert-base/
# camembert-base/LICENSE
# camembert-base/dict.txt
# camembert-base/model.pt
# camembert-base/sentencepiece.bpe.model
# --2022-03-24 00:45:47--  https://dl.fbaipublicfiles.com/fairseq/models/camembert-base.tar.gz
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.74.142, 172.67.9.4, 104.22.75.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.74.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1012630426 (966M) [application/gzip]
# Saving to: ‘camembert-base.tar.gz.1’
#
#      0K .......... .......... .......... .......... ..........  0%  977K 16m53s
#     50K .......... .......... .......... .......... ..........  0%  722K 19m51s
#    100K .......... .......... .......... .......... ..........  0% 1.47M 16m53s
#    150K .......... .......... .......... .......... ..........  0% 25.0M 12m49s
#    200K .......... .......... .......... .......... ..........  0% 59.9M 10m19s
# ...

# %%
from fairseq.models.roberta import CamembertModel
camembert = CamembertModel.from_pretrained('/content/camembert-base/')
camembert.eval()  # disable dropout (or leave in train mode to finetune)

# %%
masked_line = 'Le camembert est <mask> :)'
camembert.fill_mask(masked_line, topk=3)
# Out:
# [('Le camembert est délicieux :)', 0.49091124534606934, ' délicieux'),
#  ('Le camembert est excellent :)', 0.10556939989328384, ' excellent'),
#  ('Le camembert est succulent :)', 0.03453318402171135, ' succulent')]

# %% [markdown]
# # New code below -- TODO

# %% [markdown]
# From the plot below, we can see the most words have been classified with a >98% accuracy:

# %%
ner_extraction_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/ressources/la beubli/sentence_dataset/cleaner_ner_extraction_sentence_dataset.csv", index_col=0)
